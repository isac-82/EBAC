# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Estado'
api = requests.get(url)
print(f'Código: {api.status_code}.')
# Out:
# Código: 200.

# %%
dados_json_rj = api.json()
print(dados_json_rj['items'])
# Out:
# [{'id_pleito': 10002, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.001097/2009-67', 'data_protocolo': '2009-09-09T03:00:00Z', 'tipo_operacao': 'Operação contratual externa (com garantia da União)', 'finalidade': 'Profisco', 'tipo_credor': 'Instituição Financeira Internacional', 'credor': 'Banco Interamericano de Desenvolvimento', 'moeda': 'Dólar dos EUA', 'valor': 19759050, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '28/09/2009'}, {'id_pleito': 7085, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.000493/2012-72', 'data_protocolo': '2012-04-16T03:00:00Z', 'tipo_operacao': 'Operação contratual externa (com garantia da União)', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Internacional', 'credor': 'Corporação Andina de Fomento', 'moeda': 'Dólar dos EUA', 'valor': 120666000, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '04/10/2012'}, {'id_pleito': 5516, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.000131/2011-09', 'data_protocolo': '2011-06-30T03:00:00Z', 'tipo_operacao': 'Operação contratual externa (com garantia da União)', 'finalidade': 'Desenvolvimento sustentável', 'tipo_credor': 'Instituição Financeira Internacional', 'credor': 'Banco Internacional para Reconstrução e Desenvolvimento', 'moeda': 'Dólar dos EUA', 'valor': 485000000, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '04/07/2011'}, {'id_pleito': 21388, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': '00000.000000/2024-66', 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.000158/2016-06', 'data_protocolo': '2016-02-19T02:00:00Z', 'tipo_operacao': 'Operação contratual interna (com garantia da União)', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco Nacional de Desenvolvimento Econômico e Social', 'moeda': 'Real', 'valor': 444811123.92, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '26/02/2016'}, {'id_pleito': 7080, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.000492/2012-28', 'data_protocolo': '2012-04-16T03:00:00Z', 'tipo_operacao': 'Operação contratual externa (com garantia da União)', 'finalidade': 'Multissetorial', 'tipo_credor': 'Instituição Financeira Internacional', 'credor': 'Banco Internacional para Reconstrução e Desenvolvimento', 'moeda': 'Dólar dos EUA', 'valor': 300000000, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '03/09/2012'}, {'id_pleito': 13624, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Deferido', 'num_processo': '19405.000039/2002-72', 'data_protocolo': '2002-06-20T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco Nacional de Desenvolvimento Econômico e Social', 'moeda': 'Real', 'valor': 67482400, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '27/06/2002'}, {'id_pleito': 9750, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Deferido', 'num_processo': '17944.001046/2006-92', 'data_protocolo': '2006-07-07T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Infraestrutura', 'tipo_credor ...

# %%
df_rj = pd.DataFrame(dados_json_rj['items'])
df_rj.head()
# Out:
#    id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 0      10002           Estado  Rio de Janeiro        33  RJ
# 1       7085           Estado  Rio de Janeiro        33  RJ
# 2       5516           Estado  Rio de Janeiro        33  RJ
# 3      21388           Estado  Rio de Janeiro        33  RJ
# 4       7080           Estado  Rio de Janeiro        33  RJ
#
#                 num_pvl                                             status  \
# 0                  None  Encaminhado à PGFN com manifestação técnica fa...
# 1                  None  Encaminhado à PGFN com manifestação técnica fa...
# 2                  None  Encaminhado à PGFN com manifestação técnica fa...
# 3  00000.000000/2024-66  Encaminhado à PGFN com manifestação técnica fa...
# 4                  None  Encaminhado à PGFN com manifestação técnica fa...
#
#            num_processo        data_protocolo  \
# 0  17944.001097/2009-67  2009-09-09T03:00:00Z
# 1  17944.000493/2012-72  2012-04-16T03:00:00Z
# 2  17944.000131/2011-09  2011-06-30T03:00:00Z
# 3  17944.000158/2016-06  2016-02-19T02:00:00Z
# 4  17944.000492/2012-28  2012-04-16T03:00:00Z
#
#                                        tipo_operacao  \
# 0  Operação contratual externa (com garantia da U...
# 1  Operação contratual externa (com garantia da U...
# 2  Operação contratual externa (com garantia da U...
# 3  Operação contratual interna (com garantia da U...
# 4  Operação contratual externa (com garantia da U...
#
#                     finalidade                           tipo_credor  \
# 0                     Profisco  Instituição Financeira Internacional
# 1               Infraestrutura  Instituição Financeira Internacional
# 2  Desenvolvimento sustentável  Instituição Financeira Internacional
# 3               Infraestrutura       Instituição Financeira Nacional
# 4               Multissetorial  Instituição Financeira Internacional
#
#                                               credor          moeda  \
# 0            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 1                       Corporação Andina de Fomento  Dólar dos EUA
# 2  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 3  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 4  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
#
#           valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0  1.975905e+07                 1                      0  28/09/2009
# 1  1.206660e+08                 1                      0  04/10/2012
# 2  4.850000e+08                 1                      0  04/07/2011
# 3  4.448111e+08                 1                      0  26/02/2016
# 4  3.000000e+08                 1                      0  03/09/2012

# %%
df_rj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_pleito              52 non-null     int64
#  1   tipo_interessado       52 non-null     object
#  2   interessado            52 non-null     object
#  3   cod_ibge               52 non-null     int64
#  4   uf                     52 non-null     object
#  5   num_pvl                3 non-null      object
#  6   status                 52 non-null     object
#  7   num_processo           52 non-null     object
#  8   data_protocolo         52 non-null     object
#  9   tipo_operacao          52 non-null     object
#  10  finalidade             52 non-null     object
#  11  tipo_credor            52 non-null     object
#  12  credor                 52 non-null     object
#  13  moeda                  52 non-null     object
#  14  valor                  52 non-null     float64
#  15  pvl_assoc_divida       52 non-null     int64
#  16  pvl_contradado_credor  52 non-null     int64
#  17  data_status            52 non-null     object
# dtypes: float64(1), int64(4), object(13)
# memory usage: 7.4+ KB

# %%
# 2) Seu código aqui
df_rj['status'].value_counts()
# Out:
# Encaminhado à PGFN com manifestação técnica favorável    34
# Deferido                                                 14
# Arquivado a pedido                                        3
# Arquivado por decurso de prazo                            1
# Name: status, dtype: int64

# %%
# 3) Seu código aqui
# Formatando a data para datetime
df_rj['data_status'] = pd.to_datetime(df_rj['data_status'], format='%d/%m/%Y')

# Criando coluna ano_status só com o ano
df_rj['ano_status'] = df_rj['data_status'].dt.year

# Dataframe com status e ano
df_status_ano = df_rj[['status', 'ano_status']]
df_status_ano
# Out:
#                                                status  ano_status
# 0   Encaminhado à PGFN com manifestação técnica fa...        2009
# 1   Encaminhado à PGFN com manifestação técnica fa...        2012
# 2   Encaminhado à PGFN com manifestação técnica fa...        2011
# 3   Encaminhado à PGFN com manifestação técnica fa...        2016
# 4   Encaminhado à PGFN com manifestação técnica fa...        2012
# 5                                            Deferido        2002
# 6                                            Deferido        2006
# 7   Encaminhado à PGFN com manifestação técnica fa...        2011
# 8   Encaminhado à PGFN com manifestação técnica fa...        2011
# 9                                  Arquivado a pedido        2016
# 10  Encaminhado à PGFN com manifestação técnica fa...        2013
# 11  Encaminhado à PGFN com manifestação técnica fa...        2013
# 12                                 Arquivado a pedido        2013
# 13  Encaminhado à PGFN com manifestação técnica fa...        2009
# 14  Encaminhado à PGFN com manifestação técnica fa...        2012
# 15  Encaminhado à PGFN com manifestação técnica fa...        2013
# 16  Encaminhado à PGFN com manifestação técnica fa...        2014
# 17                                           Deferido        2002
# 18  Encaminhado à PGFN com manifestação técnica fa...        2010
# 19  Encaminhado à PGFN com manifestação técnica fa...        2009
# 20                                           Deferido        2009
# 21  Encaminhado à PGFN com manifestação técnica fa...        2009
# 22                                           Deferido        2002
# 23                                           Deferido        2009
# 24                     Arquivado por decurso de prazo        2016
# 25  Encaminhado à PGFN com manifestação técnica fa...        2012
# 26                                           Deferido        2008
# 27  Encaminhado à PGFN com manifestação técnica fa...        2016
# 28  Encaminhado à PGFN com manifestação técnica fa...        2011
# 29                                           Deferido        2010
# 30                                           Deferido        2006
# 31                                           Deferido        2011
# 32  Encaminhado à PGFN com manifestação técnica fa...        2011
# 33  Encaminhado à PGFN com manifestação técnica fa...        2009
# 34  Encaminhado à PGFN com manifestação técnica fa...        2012
# 35  Encaminhado à PGFN com manifestação técnica fa...        2009
# 36                                 Arquivado a pedido        2014
# 37  Encaminhado à PGFN com manifestação técnica fa...        2013
# 38  Encaminhado à PGFN com manifestação técnica fa...        2013
# 39                                           Deferido        2012
# 40  Encaminhado à PGFN com manifestação técnica fa...        2012
# 41                                           Deferido        2009
# 42  Encaminhado à PGFN com manifestação técnica fa...        2008
# 43  Encaminhado à PGFN com manifestação técnica fa...        2012
# 44                                           Deferido        2002
# 45  Encaminhado à PGFN com manifestação técnica fa...        2012
# 46  Encaminhado à PGFN com manifestação técnica fa...        2014
# 47  Encaminhado à PGFN com manifestação técnica fa...        2014
# 48  Encaminhado à PGFN com manifestação técnica fa...        2012
# 49                                           Deferido        2010
# 50  Encaminhado à PGFN com manifestação técnica fa...        2012
# 51  Encaminhado à PGFN com manifestação técnica fa...        2013

# %%
# 4) Seu código aqui
# Indique a frequência de cada ano do campo construído no item (3).

df_rj['ano_status'].value_counts()
# Out:
# 2012    11
# 2009     9
# 2013     7
# 2011     6
# 2016     4
# 2002     4
# 2014     4
# 2010     3
# 2006     2
# 2008     2
# Name: ano_status, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
def URL(estado:str, interessado:str):
    df = pd.DataFrame
    if interessado == 'M' or interessado == 'm':
        local = 'Munic%C3%ADpio'
    elif interessado == 'E'or interessado == 'e':
        local = 'Estado'
    url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf='+estado+'&tipo_interessado='+local
    rq = requests.get(url)
    dados = rq.json()
    df = pd.DataFrame(dados['items'])
    return df

# %%
url_mg = 'http://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=MG&tipo_interessado=Estado'
r_mg = requests.get(url_mg)
data_json_mg = r_mg.json()
df_mg = pd.DataFrame(data_json_mg['items'])
df_mg.head()
# Out:
#    id_pleito tipo_interessado   interessado  cod_ibge  uf  \
# 0       6811           Estado  Minas Gerais        31  MG
# 1      13587           Estado  Minas Gerais        31  MG
# 2      20458           Estado  Minas Gerais        31  MG
# 3       9197           Estado  Minas Gerais        31  MG
# 4      11571           Estado  Minas Gerais        31  MG
#
#                 num_pvl                                             status  \
# 0                  None  Encaminhado à PGFN com manifestação técnica fa...
# 1                  None  Encaminhado à PGFN com manifestação técnica fa...
# 2  00000.000000/2020-68                                 Arquivado a pedido
# 3                  None  Encaminhado à PGFN com manifestação técnica fa...
# 4                  None  Encaminhado à PGFN com manifestação técnica fa...
#
#            num_processo        data_protocolo  \
# 0  17944.000435/2008-62  2008-03-06T03:00:00Z
# 1  19405.000031/2004-78  2004-11-27T02:00:00Z
# 2  17944.001085/2015-81  2015-11-23T02:00:00Z
# 3  17944.000924/2009-03  2010-03-10T03:00:00Z
# 4  17944.001479/2009-91  2010-03-26T03:00:00Z
#
#                                        tipo_operacao             finalidade  \
# 0  Operação contratual externa (com garantia da U...         Multissetorial
# 1  Operação contratual externa (com garantia da U...  Desenvolvimento rural
# 2  Operação contratual externa (com garantia da U...         Multissetorial
# 3  Operação contratual externa (com garantia da U...         Infraestrutura
# 4  Operação contratual externa (com garantia da U...         Multissetorial
#
#                             tipo_credor  \
# 0  Instituição Financeira Internacional
# 1  Instituição Financeira Internacional
# 2  Instituição Financeira Internacional
# 3  Instituição Financeira Internacional
# 4  Instituição Financeira Internacional
#
#                                               credor          moeda  \
# 0  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 1  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 2            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 3            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 4  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
#
#          valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0  976000000.0                 1                      0  02/07/2008
# 1   35000000.0                 1                      0  09/12/2004
# 2   50000000.0                 0                      0  29/04/2016
# 3   50000000.0                 1                      0  01/04/2010
# 4  461000000.0                 1                      0  01/04/2010

# %%
# 2) Seu código aqui

arquivado = df_mg.loc[df_mg.status == 'Arquivado por decurso de prazo']
arquivado['status'].value_counts()
# Out:
# Arquivado por decurso de prazo    1
# Name: status, dtype: int64

# %%
# 3) Seu código aqui# 3) Seu código aqui
df = URL('BA','m')
var = df[df['status']=='Deferido'].interessado.value_counts()
display(var)
# Out:
# Luís Eduardo Magalhães    14
# Vitória da Conquista      11
# Camaçari                  10
# Lauro de Freitas          10
# Barreiras                  9
#                           ..
# Santana                    1
# Pedrão                     1
# Licínio de Almeida         1
# São Francisco do Conde     1
# Amélia Rodrigues           1
# Name: interessado, Length: 176, dtype: int64

# %%
# 4) Seu código aqui
url_ba_estado = 'http://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=BA&tipo_interessado=Estado'
r_ba_estado = requests.get(url_ba_estado)
data_json_ba_estado = r_ba_estado.json()
df_ba_estado = pd.DataFrame(data_json_ba_estado['items'])
df_ba_estado.head()
# Out:
#    id_pleito tipo_interessado interessado  cod_ibge  uf               num_pvl  \
# 0      18555           Estado       Bahia        29  BA                  None
# 1      18356           Estado       Bahia        29  BA                  None
# 2      18354           Estado       Bahia        29  BA                  None
# 3       6334           Estado       Bahia        29  BA                  None
# 4      42037           Estado       Bahia        29  BA  PVL02.007745/2019-06
#
#                                               status          num_processo  \
# 0                                           Deferido  19407.000050/2002-12
# 1  Encaminhado à PGFN com manifestação técnica fa...  19407.000006/2003-93
# 2  Encaminhado à PGFN com manifestação técnica fa...  19407.000005/2006-91
# 3  Encaminhado à PGFN com manifestação técnica fa...  17944.000322/2013-24
# 4                                           Deferido  17944.101173/2020-49
#
#          data_protocolo                                      tipo_operacao  \
# 0  2002-06-11T03:00:00Z                        Operação contratual interna
# 1  2003-03-31T03:00:00Z  Operação contratual externa (com garantia da U...
# 2  2006-01-31T02:00:00Z  Operação contratual externa (com garantia da U...
# 3  2013-08-26T03:00:00Z  Operação contratual interna (com garantia da U...
# 4  2020-03-24T20:42:47Z                        Operação contratual interna
#
#                     finalidade                           tipo_credor  \
# 0            Saneamento básico       Instituição Financeira Nacional
# 1  Desenvolvimento sustentável  Instituição Financeira Internacional
# 2  Desenvolvimento sustentável  Instituição Financeira Internacional
# 3               Multissetorial       Instituição Financeira Nacional
# 4               Infraestrutura       Instituição Financeira Nacional
#
#                                               credor          moeda  \
# 0                            Caixa Econômica Federal           Real
# 1  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 2    Fundo Internacional de Desenvolvimento Agrícola  Dólar dos EUA
# 3                                Banco do Brasil S/A           Real
# 4                                Banco do Brasil S/A           Real
#
#           valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0  6.774733e+05                 1                      0  05/07/2002
# 1  6.000000e+07                 1                      0  30/10/2003
# 2  3.000000e+07                 1                      0  04/07/2006
# 3  1.125480e+09                 1                      1  10/09/2013
# 4  2.500000e+08                 1                      1  25/03/2020

# %%
df_ba_estado.to_csv('./df_ba_estado.csv', index= False, encoding='utf-8-sig', sep=';')
